# %% [markdown]
# <a href="https://colab.research.google.com/github/BuhariS/DataScienceWithPython/blob/main/AirQo_African_Air_Quality_Prediction_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Load data

# %%
sample_sub_df = pd.read_csv('/content/drive/MyDrive/Personal Development/competitions/SampleSubmission.csv')
train_df = pd.read_csv('/content/drive/MyDrive/Personal Development/competitions/Train.csv')
test_df = pd.read_csv('/content/drive/MyDrive/Personal Development/competitions/Test.csv')

# %% [markdown]
# **Data snapshot**

# %%
train_df.head(3)
# Out:
#               id                   site_id  site_latitude  site_longitude  \
# 0  id_vjcx08sz91  6531a46a89b3300013914a36        6.53257         3.39936
# 1  id_bkg215syli  6531a46a89b3300013914a36        6.53257         3.39936
# 2  id_oui2pot3qd  6531a46a89b3300013914a36        6.53257         3.39936
#
#     city  country        date  hour  sulphurdioxide_so2_column_number_density  \
# 0  Lagos  Nigeria  2023-10-25    13                                       NaN
# 1  Lagos  Nigeria  2023-11-02    12                                       NaN
# 2  Lagos  Nigeria  2023-11-03    13                                       NaN
#
#    sulphurdioxide_so2_column_number_density_amf  ...  cloud_cloud_top_height  \
# 0                                           NaN  ...                     NaN
# 1                                           NaN  ...                     NaN
# 2                                           NaN  ...             6791.682888
#
#    cloud_cloud_base_pressure  cloud_cloud_base_height  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2               51171.802486              5791.682829
#
#    cloud_cloud_optical_depth  cloud_surface_albedo  \
# 0                        NaN                   NaN
# 1                        NaN                   NaN
# 2                  11.816715              0.192757
#
#    cloud_sensor_azimuth_angle  cloud_sensor_zenith_angle  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                   -96.41189                  61.045123
#
#    cloud_solar_azimuth_angle  cloud_solar_zenith_angle      pm2_5
# 0                        NaN                       NaN  12.015000
# 1                        NaN                       NaN  42.267200
# 2                -121.307414                 41.898269  39.450741
#
# [3 rows x 80 columns]

# %%
test_df.head(3)
# Out:
#               id                   site_id  site_latitude  site_longitude  \
# 0  id_ihxgrbq8bw  64f9d17ab9e98d001ac9e882        5.61252        -0.22955
# 1  id_dg6s4fhiwe  64f9d17ab9e98d001ac9e882        5.61252        -0.22955
# 2  id_f7hwwtmuzp  64f9d17ab9e98d001ac9e882        5.61252        -0.22955
#
#     city country        date  hour  sulphurdioxide_so2_column_number_density  \
# 0  Accra   Ghana  2023-09-06    13                                 -0.000072
# 1  Accra   Ghana  2023-09-07    13                                       NaN
# 2  Accra   Ghana  2023-09-08    13                                 -0.000051
#
#    sulphurdioxide_so2_column_number_density_amf  ...  \
# 0                                      0.762543  ...
# 1                                           NaN  ...
# 2                                      1.004265  ...
#
#    cloud_cloud_top_pressure  cloud_cloud_top_height  \
# 0              74217.403083             2710.544562
# 1                       NaN                     NaN
# 2                       NaN                     NaN
#
#    cloud_cloud_base_pressure  cloud_cloud_base_height  \
# 0               83569.504246              1710.544483
# 1                        NaN                      NaN
# 2                        NaN                      NaN
#
#    cloud_cloud_optical_depth  cloud_surface_albedo  \
# 0                   3.063105              0.263193
# 1                        NaN                   NaN
# 2                        NaN                   NaN
#
#    cloud_sensor_azimuth_angle  cloud_sensor_zenith_angle  \
# 0                 -100.317077                  27.059646
# 1                         NaN                        NaN
# 2                         NaN                        NaN
#
#    cloud_solar_azimuth_angle  cloud_solar_zenith_angle
# 0                  -86.88567                 25.530511
# 1                        NaN                       NaN
# 2                        NaN                       NaN
#
# [3 rows x 79 columns]

# %%
sample_sub_df.head(3)
# Out:
#               id  pm2_5
# 0  id_ihxgrbq8bw      0
# 1  id_dg6s4fhiwe      0
# 2  id_f7hwwtmuzp      0

# %% [markdown]
# **Dataset metadata**

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8071 entries, 0 to 8070
# Data columns (total 80 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   id                                                        8071 non-null   object
#  1   site_id                                                   8071 non-null   object
#  2   site_latitude                                             8071 non-null   float64
#  3   site_longitude                                            8071 non-null   float64
#  4   city                                                      8071 non-null   object
#  5   country                                                   8071 non-null   object
#  6   date                                                      8071 non-null   object
#  7   hour                                                      8071 non-null   int64
#  8   sulphurdioxide_so2_column_number_density                  3159 non-null   float64
#  9   sulphurdioxide_so2_column_number_density_amf              3159 non-null   float64
#  10  sulphurdioxide_so2_slant_column_number_density            3159 non-null   float64
#  11  sulphurdioxide_cloud_fraction                             3159 non-null   float64
#  12  sulphurdioxide_sensor_azimuth_angle                       3159 non-null   float64
#  13  sulphurdioxide_sensor_zenith_angle                        3159 non-null   float64
#  14  sulphurdioxide_solar_azimuth_angle                        3159 non-null   float64
#  15  sulphurdioxide_solar_zenith_angle                         3159 non-null   float64
#  16  sulphurdioxide_so2_column_number_density_15km             3159 non-null   float64
#  17  month                                                     8071 non-null   float64
#  18  carbonmonoxide_co_column_number_density                   4441 non-null   float64
#  19  carbonmonoxide_h2o_column_number_density                  4441 non-null   float64
#  20  carbonmonoxide_cloud_height                               4441 non-null   float64
#  21  carbonmonoxide_sensor_altitude                            4441 non-null   float64
#  22  carbonmonoxide_sensor_azimuth_angle                       4441 non-null   float64
#  23  carbonmonoxide_sensor_zenith_angle                        4441 non-null   float64
#  24  carbonmonoxide_solar_azimuth_angle                        4441 non-null   float64
#  25  carbonmonoxide_solar_zenith_angle                         4441 non-null   float64
#  26  nitrogendioxide_no2_column_number_density                 3104 non-null   float64
#  27  nitrogendioxide_tropospheric_no2_column_number_density    3104 non-null   float64
#  28  nitrogendioxide_stratospheric_no2_column_number_density   3104 non-null   float64
#  29  nitrogendioxide_no2_slant_column_number_density           3104 non-null   float64
#  30  nitrogendioxide_tropopause_pressure                       3104 non-null   float64
#  31  nitrogendioxide_absorbing_aerosol_index                   3104 non-null   float64
#  32  nitrogendioxide_cloud_fraction                            3104 non-null   float64
#  33  nitrogendioxide_sensor_altitude                           3104 non-null   float64
#  34  nitrogendioxide_sensor_azimuth_angle                      3104 non-null   float64
#  35  nitrogendioxide_sensor_zenith_angle                       3104 non-null   float64
#  36  nitrogendioxide_solar_azimuth_angle                       3104 non-null   float64
#  37  nitrogendioxide_solar_zenith_angle                        3104 non-null   float64
#  38  formaldehyde_tropospheric_hcho_column_number_density      4156 non-null   float64
#  39  formaldehyde_tropospheric_hcho_column_number_density_amf  4156 non-null   float64
#  40  formaldehyde_hcho_slant_column_number_density             4156 non-null   float64
#  41  formaldehyde_cloud_fraction                               4156 non-null   float64
#  42  formaldehyde_solar_zenith_angle                           4156 non-null   float64
#  43  formaldehyde_solar_azimuth_angle                          4156 non-null   float64
#  44  formaldehyde_sensor_zenith_angle                          4156 non-null   float64
#  45  formaldehyde_sensor_azimuth_angle                         4156 non-null   float64
#  46  uvaerosolindex_absorbing_aerosol_index                    8066 non-null   float64
#  47  uvaerosolindex_sensor_altitude                            8066 non-null   float64
#  48  uvaerosolindex_sensor_azimuth_angle                       8066 non-null   float64
#  49  uvaerosolindex_sensor_zenith_angle                        8066 non-null   float64
#  50  uvaerosolindex_solar_azimuth_angle                        8066 non-null   float64
#  51  uvaerosolindex_solar_zenith_angle                         8066 non-null   float64
#  52  ozone_o3_column_number_density                            7959 non-null   float64
#  53  ozone_o3_column_number_density_amf                        7959 non-null   float64
#  54  ozone_o3_slant_column_number_density                      7959 non-null   float64
#  55  ozone_o3_effective_temperature                            7959 non-null   float64
#  56  ozone_cloud_fraction                                      7959 non-null   float64
#  57  ozone_sensor_azimuth_angle                                7959 non-null   float64
#  58  ozone_sensor_zenith_angle                                 7959 non-null   float64
#  59  ozone_solar_azimuth_angle                                 7959 non-null   float64
#  60  ozone_solar_zenith_angle                                  7959 non-null   float64
#  61  uvaerosollayerheight_aerosol_height                       427 non-null    float64
#  62  uvaerosollayerheight_aerosol_pressure                     427 non-null    float64
#  63  uvaerosollayerheight_aerosol_optical_depth                427 non-null    float64
#  64  uvaerosollayerheight_sensor_zenith_angle                  427 non-null    float64
#  65  uvaerosollayerheight_sensor_azimuth_angle                 427 non-null    float64
#  66  uvaerosollayerheight_solar_azimuth_angle                  427 non-null    float64
#  67  uvaerosollayerheight_solar_zenith_angle                   427 non-null    float64
#  68  cloud_cloud_fraction                                      4994 non-null   float64
#  69  cloud_cloud_top_pressure                                  4994 non-null   float64
#  70  cloud_cloud_top_height                                    4994 non-null   float64
#  71  cloud_cloud_base_pressure                                 4994 non-null   float64
#  72  cloud_cloud_base_height                                   4994 non-null   float64
#  73  cloud_cloud_optical_depth                                 4994 non-null   float64
#  74  cloud_surface_albedo                                      4994 non-null   float64
#  75  cloud_sensor_azimuth_angle                                4994 non-null   float64
#  76  cloud_sensor_zenith_angle                                 4994 non-null   float64
#  77  cloud_solar_azimuth_angle                                 4994 non-null   float64
#  78  cloud_solar_zenith_angle                                  4994 non-null   float64
#  79  pm2_5                                                     8071 non-null   float64
# dtypes: float64(74), int64(1), object(5)
# memory usage: 4.9+ MB

# %%
train_df.describe().T
# Out:
#                                                count       mean        std  \
# site_latitude                                 8071.0   0.635678   2.154605
# site_longitude                                8071.0  30.246982   9.393151
# hour                                          8071.0  10.877463   0.815875
# sulphurdioxide_so2_column_number_density      3159.0   0.000024   0.000354
# sulphurdioxide_so2_column_number_density_amf  3159.0   0.687295   0.142544
# ...                                              ...        ...        ...
# cloud_sensor_azimuth_angle                    4994.0 -18.952179  85.873938
# cloud_sensor_zenith_angle                     4994.0  45.881380  14.721454
# cloud_solar_azimuth_angle                     4994.0 -84.811978  40.627170
# cloud_solar_zenith_angle                      4994.0  28.708028   7.038309
# pm2_5                                         8071.0  24.639296  24.878920
#
#                                                      min         25%  \
# site_latitude                                  -3.459970    0.288630
# site_longitude                                  3.201510   32.568643
# hour                                           10.000000   10.000000
# sulphurdioxide_so2_column_number_density       -0.000980   -0.000196
# sulphurdioxide_so2_column_number_density_amf    0.299364    0.589849
# ...                                                  ...         ...
# cloud_sensor_azimuth_angle                   -102.706078  -98.865659
# cloud_sensor_zenith_angle                       2.996863   37.901279
# cloud_solar_azimuth_angle                    -159.058782 -125.371559
# cloud_solar_zenith_angle                       10.314990   24.102775
# pm2_5                                           1.200000   13.270600
#
#                                                     50%        75%         max
# site_latitude                                  0.332610   0.374653    6.595400
# site_longitude                                32.600480  32.641110   36.914272
# hour                                          11.000000  11.000000   14.000000
# sulphurdioxide_so2_column_number_density       0.000012   0.000221    0.002024
# sulphurdioxide_so2_column_number_density_amf   0.669632   0.766817    1.607052
# ...                                                 ...        ...         ...
# cloud_sensor_azimuth_angle                   -97.477511  72.814735   77.319656
# cloud_sensor_zenith_angle                     49.187592  57.156175   66.238778
# cloud_solar_azimuth_angle                    -74.597511 -49.902340  -22.251009
# cloud_solar_zenith_angle                      29.002745  33.929767   45.496395
# pm2_5                                         18.375400  28.838400  456.193333
#
# [75 rows x 8 columns]

# %% [markdown]
# **Observation**
#
# - Latitude and longitude have valid entries, may need transformation
# - hour ranges from 10:00 AM to 2:00 PM
# - the count of all so2 is 3104
# - site id seems to be having the same info as city and country
# - date can be separated to its constituent numbers
# - replace nans with grouped averages
#
# ## Merge test and train

# %%
train_predictors = train_df.drop('pm2_5', axis=1)

# %%
def process_data(train_df, test_df):
    """
    Process the training and testing DataFrames as specified.

    Args:
        train_df (pandas.DataFrame): The training DataFrame.
        test_df (pandas.DataFrame): The testing DataFrame.

    Returns:
        tuple: A tuple containing two processed DataFrames (processed_train, processed_test).
    """
    # Stack the training predictors and test data vertically
    stacked_df = pd.concat([train_df, test_df], axis=0)

    # Perform one-hot encoding for specified columns
    dum_data_df = pd.get_dummies(stacked_df, columns=['site_id', 'city', 'country'], drop_first=True)

    # Separate processed data back into training and testing DataFrames
    processed_train = dum_data_df.iloc[:len(train_df)]
    processed_test = dum_data_df.iloc[len(train_df):]

    return processed_train, processed_test

# %%
processed_train, processed_test = process_data(train_predictors, test_df)

# %% [markdown]
# ## Transform

# %%
def transform_dataframe(df):
    # Drop 'id' column
    df = df.drop('id', axis=1)

    # Convert 'date' column to datetime
    df['date'] = pd.to_datetime(df['date'])

    # Extract 'year' from 'date' column
    df['year'] = df['date'].dt.year

    # Drop 'date' column
    df = df.drop('date', axis=1)

    # Replace null values with 0
    df = df.fillna(0)

    return df

# %%
# Example usage:
transformed_train = transform_dataframe(processed_train)

# %%
# Example usage:
transformed_test = transform_dataframe(processed_test)

# %% [markdown]
# ## Scaling

# %%
def scale_data(df):
    """
    Scales the input DataFrame using StandardScaler.

    Args:
        df (pandas.DataFrame): Input DataFrame to be scaled.

    Returns:
        numpy.ndarray: Scaled data.
    """
    # Initialize StandardScaler
    scaler = StandardScaler()

    # Fit the scaler to the data and transform the data
    X_scaled = scaler.fit_transform(df)

    return X_scaled

# %%
X_scaled_train = scale_data(transformed_train)

# %%
X_scaled_test = scale_data(transformed_test)

# %%
y = train_df['pm2_5']

# %% [markdown]
# ## Train and evaluate

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

def train_test_model(predictors, target, model):
    """
    Train a model on the provided predictors and target, make predictions, and return RMSE.

    Args:
        predictors (pandas.DataFrame or numpy.ndarray): Predictors/features.
        target (pandas.Series or numpy.ndarray): Target variable.
        model: The machine learning model to be trained.

    Returns:
        float: Root Mean Squared Error (RMSE) of the model's predictions.
    """
    # Split the data into train and test sets (80% train, 20% test)
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.2, random_state=42)

    # Fit the model to the training data
    model.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = model.predict(X_test)

    # Calculate RMSE
    rmse = sqrt(mean_squared_error(y_test, y_pred))

    return rmse

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
# Example usage
model = LinearRegression()
r_model = RandomForestRegressor()
rmse = train_test_model(X_scaled_train, y, r_model)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Root Mean Squared Error (RMSE): 16.748629566304647

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 17.835869266917996

# %%
r_model = RandomForestRegressor()

# %%
r_model.fit(X_scaled_train, y)

# %%
y_pred = r_model.predict(X_scaled_test)

# %%
mean_squared_error(y_test, y_pred, squared=False)

# %% [markdown]
# **Test many**

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import BayesianRidge

def compare_regression_models(predictors, target):
    """
    Compare the performance of multiple regression models using RMSE.

    Args:
        predictors (pandas.DataFrame or numpy.ndarray): Predictors/features.
        target (pandas.Series or numpy.ndarray): Target variable.

    Returns:
        pandas.DataFrame: DataFrame of models with their respective RMSE arranged in ascending order.
    """
    # Instantiate regressor models
    models = [
        LinearRegression(),
        Ridge(),
        Lasso(),
        ElasticNet(),
        SVR(),
        DecisionTreeRegressor(),
        RandomForestRegressor(),
        GradientBoostingRegressor(),
        KNeighborsRegressor(),
        BayesianRidge()
    ]

    # Dictionary to store model names and their RMSE
    model_rmse = {}

    # Train each model and calculate RMSE
    for model in models:
        model_name = model.__class__.__name__
        rmse = train_test_model(predictors, target, model)
        model_rmse[model_name] = rmse

    # Create DataFrame from model_rmse dictionary
    rmse_df = pd.DataFrame(list(model_rmse.items()), columns=['Model', 'RMSE'])

    # Sort DataFrame by RMSE in ascending order
    rmse_df = rmse_df.sort_values(by='RMSE')

    return rmse_df

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import HuberRegressor
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor
from sklearn.neural_network import MLPRegressor

def compare_regression_models2(predictors, target):
    """
    Compare the performance of multiple regression models using RMSE.

    Args:
        predictors (pandas.DataFrame or numpy.ndarray): Predictors/features.
        target (pandas.Series or numpy.ndarray): Target variable.

    Returns:
        pandas.DataFrame: DataFrame of models with their respective RMSE arranged in ascending order.
    """
    # Instantiate regressor models
    models = [
        LinearRegression(),
        Ridge(),
        Lasso(),
        ElasticNet(),
        SVR(),
        DecisionTreeRegressor(),
        RandomForestRegressor(),
        GradientBoostingRegressor(),
        KNeighborsRegressor(),
        BayesianRidge(),
        AdaBoostRegressor(),
        HuberRegressor(),
        PassiveAggressiveRegressor(),
        TheilSenRegressor(),
        MLPRegressor()
    ]

    # Dictionary to store model names and their RMSE
    model_rmse = {}

    # Train each model and calculate RMSE
    for model in models:
        model_name = model.__class__.__name__
        rmse = train_test_model(predictors, target, model)
        model_rmse[model_name] = rmse

    # Create DataFrame from model_rmse dictionary
    rmse_df = pd.DataFrame(list(model_rmse.items()), columns=['Model', 'RMSE'])

    # Sort DataFrame by RMSE in ascending order
    rmse_df = rmse_df.sort_values(by='RMSE')

    return rmse_df

# %%
compare_regression_models(X_scaled_train, y)
# Out:
#                        Model       RMSE
# 6      RandomForestRegressor  16.678700
# 9              BayesianRidge  17.573038
# 1                      Ridge  17.640094
# 7  GradientBoostingRegressor  17.681601
# 0           LinearRegression  17.699530
# 2                      Lasso  18.753111
# 8        KNeighborsRegressor  18.903024
# 3                 ElasticNet  19.440097
# 5      DecisionTreeRegressor  21.736285
# 4                        SVR  24.532587

# %%
compare_regression_models2(X_scaled_train, y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_huber.py:342: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#                          Model       RMSE
# 6        RandomForestRegressor  16.865870
# 14                MLPRegressor  16.911410
# 9                BayesianRidge  17.573038
# 1                        Ridge  17.640094
# 7    GradientBoostingRegressor  17.690142
# 0             LinearRegression  17.699530
# 11              HuberRegressor  18.027459
# 2                        Lasso  18.753111
# 8          KNeighborsRegressor  18.903024
# 3                   ElasticNet  19.440097
# 5        DecisionTreeRegressor  21.604395
# 12  PassiveAggressiveRegressor  23.318853
# 4                          SVR  24.532587
# 13           TheilSenRegressor  27.744469
# 10           AdaBoostRegressor  29.118376

# %% [markdown]
# ## Fine tuning random forest

# %%
# Split the data into train and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled_train, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt'],
    'bootstrap': [True, False]
}

# Instantiate Random Forest Regressor
rf_regressor = RandomForestRegressor()

# Perform grid search
grid_search = GridSearchCV(estimator=rf_regressor, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(X_train, y_train)

# Get the best parameters and best estimator
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

# Fit the model using the best parameters
best_estimator.fit(X_train, y_train)

# Evaluate the model
y_pred = best_estimator.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("Root Mean Squared Error:", rmse)

# %% [markdown]
# ## Generate submission

# %%
def predict_with_model(predictors, target, model):
    """
    Make predictions using the provided model.

    Args:
        predictors (pandas.DataFrame or numpy.ndarray): Predictors/features.
        target (pandas.Series or numpy.ndarray): Target variable.
        model: The machine learning model.

    Returns:
        numpy.ndarray: Predicted target variable.
    """
    # Fit the model to all data
    model.fit(predictors, target)

    # Make predictions
    y_pred = model.predict(X_scaled_test)

    return y_pred

# %%
y_pred = predict_with_model(X_scaled_train, y, model)

# %%
y_pred
# Out:
# array([2.78534343e+13, 2.78534343e+13, 2.78534343e+13, ...,
#        1.37632009e+13, 1.37632009e+13, 1.37632009e+13])

# %%
sample_sub_df['pm2_5'] = y_pred

# %%
sample_sub_df.to_csv('submission.csv', index=False)
